# %%
from huggingface_hub import InferenceClient
from IPython.display import display
client = InferenceClient()
image = client.text_to_image("dogs on with space suit ")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x204712FB5B0>
